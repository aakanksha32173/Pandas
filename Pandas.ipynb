# %% [markdown]
# <a href="https://colab.research.google.com/github/aakanksha32173/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#Reading a csv file
df=pd.read_csv("/content/weatherHistory.csv")
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
#Displaying columns of dataframe
df.keys()
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
#displaying maximum temperature
df['Temperature (C)'].max()
# Out:
# 39.90555555555555

# %%
#checking dates when it is raining
df['Formatted Date'][df['Precip Type']=='rain']
# Out:
# 0        2006-04-01 00:00:00.000 +0200
# 1        2006-04-01 01:00:00.000 +0200
# 2        2006-04-01 02:00:00.000 +0200
# 3        2006-04-01 03:00:00.000 +0200
# 4        2006-04-01 04:00:00.000 +0200
#                      ...
# 96448    2016-09-09 19:00:00.000 +0200
# 96449    2016-09-09 20:00:00.000 +0200
# 96450    2016-09-09 21:00:00.000 +0200
# 96451    2016-09-09 22:00:00.000 +0200
# 96452    2016-09-09 23:00:00.000 +0200
# Name: Formatted Date, Length: 85224, dtype: object

# %%
#calculating average speed of wind
average(df['Wind Speed (km/h)'])
# Out:
# 10.810640140793963

# %%
#2nd way
df['Wind Speed (km/h)'].mean()
# Out:
# 10.810640140793963

# %%
#gathering information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
#checking the number of null values in dataset
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
#substituting the null values in Precip type with No rain marking inplace=True to reflect changes in original dataframe
df.fillna('No rain',inplace=True)

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df['Daily Summary'][df['Precip Type']=='No rain']
# Out:
# 52672                  Mostly cloudy until night.
# 52674                  Mostly cloudy until night.
# 52675                  Mostly cloudy until night.
# 52677                  Mostly cloudy until night.
# 52678                  Mostly cloudy until night.
#                            ...
# 95584    Mostly cloudy starting in the afternoon.
# 95585    Mostly cloudy starting in the afternoon.
# 95586    Mostly cloudy starting in the afternoon.
# 95587    Mostly cloudy starting in the afternoon.
# 95588    Mostly cloudy starting in the afternoon.
# Name: Daily Summary, Length: 517, dtype: object

# %%
#creating dataframe from a dictionary
weather_data={
    'Day':['1/01/2001','2/02/2001','5/12/2001','6/06/2001'],
    'Temp':['34','45','88','67'],
    'Wind Speed':['32','65','76','76'],
    'Event':['rain','no rain','rain','no rain']
}
df2=pd.DataFrame(weather_data)
df2
# Out:
#          Day Temp Wind Speed    Event
# 0  1/01/2001   34         32     rain
# 1  2/02/2001   45         65  no rain
# 2  5/12/2001   88         76     rain
# 3  6/06/2001   67         76  no rain

# %%
rows,columns=df2.shape

# %%
rows
# Out:
# 4

# %%
columns
# Out:
# 4

# %%
df.head(5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.tail(45)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96408  2016-09-08 03:00:00.000 +0200  Partly Cloudy        rain
# 96409  2016-09-08 04:00:00.000 +0200  Partly Cloudy        rain
# 96410  2016-09-08 05:00:00.000 +0200  Mostly Cloudy        rain
# 96411  2016-09-08 06:00:00.000 +0200  Mostly Cloudy        rain
# 96412  2016-09-08 07:00:00.000 +0200  Mostly Cloudy        rain
# 96413  2016-09-08 08:00:00.000 +0200  Mostly Cloudy        rain
# 96414  2016-09-08 09:00:00.000 +0200  Partly Cloudy        rain
# 96415  2016-09-08 10:00:00.000 +0200  Mostly Cloudy        rain
# 96416  2016-09-08 11:00:00.000 +0200  Mostly Cloudy        rain
# 96417  2016-09-08 12:00:00.000 +0200  Partly Cloudy        rain
# 96418  2016-09-08 13:00:00.000 +0200  Partly Cloudy        rain
# 96419  2016-09-08 14:00:00.000 +0200  Partly Cloudy        rain
# 96420  2016-09-08 15:00:00.000 +0200  Partly Cloudy        rain
# 96421  2016-09-08 16:00:00.000 +0200  Partly Cloudy        rain
# ...

# %%
df[2:5]
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.Summary
# Out:
# 0        Partly Cloudy
# 1        Partly Cloudy
# 2        Mostly Cloudy
# 3        Partly Cloudy
# 4        Mostly Cloudy
#              ...
# 96448    Partly Cloudy
# 96449    Partly Cloudy
# 96450    Partly Cloudy
# 96451    Partly Cloudy
# 96452    Partly Cloudy
# Name: Summary, Length: 96453, dtype: object

# %%
df[['Apparent Temperature (C)', 'Humidity']].head(10)
# Out:
#    Apparent Temperature (C)  Humidity
# 0                  7.388889      0.89
# 1                  7.227778      0.86
# 2                  9.377778      0.89
# 3                  5.944444      0.83
# 4                  6.977778      0.83
# 5                  7.111111      0.85
# 6                  5.522222      0.95
# 7                  6.527778      0.89
# 8                 10.822222      0.82
# 9                 13.772222      0.72

# %%
#works on numerical data
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
type('Formatted Date')
# Out:
# str

# %%
df[['Apparent Temperature (C)','Temperature (C)']][df['Temperature (C)']>32]
# Out:
#        Apparent Temperature (C)  Temperature (C)
# 732                   32.222222        32.172222
# 733                   31.272222        32.127778
# 735                   32.688889        32.538889
# 737                   32.511111        32.011111
# 952                   32.911111        32.172222
# ...                         ...              ...
# 92506                 32.883333        32.083333
# 92507                 32.072222        32.033333
# 92508                 33.361111        32.622222
# 92509                 32.800000        32.644444
# 92510                 32.538889        32.394444
#
# [1587 rows x 2 columns]

# %%
df[df['Temperature (C)']==df['Temperature (C)'].max()]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 12759  2007-07-22 15:00:00.000 +0200   Clear        rain        39.905556
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12759                 37.538889      0.13            23.5865
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12759                   250.0            9.982         0.0
#
#        Pressure (millibars)                             Daily Summary
# 12759               1007.55  Partly cloudy starting in the afternoon.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
df.set_index('Formatted Date',inplace=True)

# %%
df
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# ...                                      ...         ...              ...
# 2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain        26.016667
# 2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain        24.583333
# 2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain        22.038889
# 2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain        21.522222
# 2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain        20.438889
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.set_index('Precip Type',inplace =True)

# %%
df
# Out:
#                             Formatted Date        Summary  \
# Precip Type
# rain         2006-04-01 00:00:00.000 +0200  Partly Cloudy
# rain         2006-04-01 01:00:00.000 +0200  Partly Cloudy
# rain         2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# rain         2006-04-01 03:00:00.000 +0200  Partly Cloudy
# rain         2006-04-01 04:00:00.000 +0200  Mostly Cloudy
# ...                                    ...            ...
# rain         2016-09-09 19:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 20:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 21:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 22:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 23:00:00.000 +0200  Partly Cloudy
#
#              Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# Precip Type
# rain                         7.388889      0.89            14.1197
# rain                         7.227778      0.86            14.2646
# ...

# %%
df.loc['rain']
# Out:
#                             Formatted Date        Summary  \
# Precip Type
# rain         2006-04-01 00:00:00.000 +0200  Partly Cloudy
# rain         2006-04-01 01:00:00.000 +0200  Partly Cloudy
# rain         2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# rain         2006-04-01 03:00:00.000 +0200  Partly Cloudy
# rain         2006-04-01 04:00:00.000 +0200  Mostly Cloudy
# ...                                    ...            ...
# rain         2016-09-09 19:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 20:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 21:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 22:00:00.000 +0200  Partly Cloudy
# rain         2016-09-09 23:00:00.000 +0200  Partly Cloudy
#
#              Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# Precip Type
# rain                         7.388889      0.89            14.1197
# rain                         7.227778      0.86            14.2646
# ...
